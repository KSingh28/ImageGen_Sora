# %%
# %pip install openai==1.64.0 | tail -n 1
# Out:
# Successfully installed jiter-0.14.0 openai-1.64.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI
from IPython import display

client = OpenAI()

response = client.images.generate(
    model="dall-e-2",
    prompt="a white siamese cat",
    size="1024x1024",
    # quality="standard",
    n=1,
)

url = response.data[0].url
display.Image(url=url, width=512)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-434DgKVrfIjWvK9YEpzlrvmq/labs-api-proxy-service-account/img-5zpIxNu1VPooDS3fQlb6vOBc.png?st=2026-04-29T17%3A11%3A02Z&se=2026-04-29T19%3A11%3A02Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=8eb2c87c-0531-4dab-acb3-b5e2adddce6c&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-04-29T16%3A43%3A33Z&ske=2026-04-30T16%3A43%3A33Z&sks=b&skv=2026-02-06&sig=BdpZXpkHfZ%2BS4UGpzxFtJlejpsT2BE8HDbugEYPqJuY%3D" width="512"/>
